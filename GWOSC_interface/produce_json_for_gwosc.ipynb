# %%
import dataclasses
import json

import ias_schema

# %%
catalog = ias_schema.make_catalog()

# %%
with open('ias-o3a.json', 'w') as file:
    # json.dump(dataclasses.asdict(catalog), file, indent=2)
    text = (json.dumps(dataclasses.asdict(catalog), indent=2)
            .replace('waveform_family', 'waveform-family')
            .replace('data_url', 'data-url'))
    file.write(text)

# %% [markdown]
# ### Notes
# * Is there a use for `upper_limit`, `lower_limit`? Otherwise remove
# * `best`, `lower`, `upper` is ambiguous
